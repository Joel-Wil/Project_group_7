# %%
import numpy as np
import math
from scipy.optimize import linear_sum_assignment


def euclidianDistance(p1,p2):
    return np.linalg.norm(np.array(p1) - np.array(p2))

def polar_to_cartesian(magnitude, angle_rad):
    x = magnitude * np.cos(angle_rad)
    y = magnitude * np.sin(angle_rad)
    return np.array([x, y])

def cosine_similarity(v1Polar, v2Polar):
    v1Cartesian = polar_to_cartesian(v1Polar[0], v1Polar[1])
    v2Cartesian = polar_to_cartesian(v2Polar[0], v2Polar[1])
    return np.dot(v1Cartesian, v2Cartesian) / (np.linalg.norm(v1Cartesian) * np.linalg.norm(v2Cartesian))

def Vector(fromCoord, toCoord, latency):
        if latency < 1e-5:
            return 0, 0
        else:
            magnitude = euclidianDistance(fromCoord, toCoord) / latency
            radians = math.atan2(toCoord[1] - fromCoord[1], toCoord[0] - fromCoord[0])
            if radians < 0: #to get positive radian values (to get true fraction)
                radians = (2*math.pi)+radians
            return magnitude, radians


'''
vid upptäckt markera med röd ring
om fler än 10 koordinater registreras på samma id, kör på som vanligt
'''

class OBJECT():
    def __init__(self, id, initialCoord, time):
        self.id = id
        self.trajectory = []
        self.vectors = []
        self.avg_vector_short = None
        self.avg_vector_long = None
        self.diff_avg_magnitude = 0
        self.clock = time
        self.latency = 0
        self.fresh = False

        self.preliminary_trajectory = [(initialCoord, time)]
        self.nmbr_of_coord_id = 0
        '''
        to track ALL data (CSV)
        '''
        self.data = []

    def addCoordinate(self, coordinate, time):
        if self.nmbr_of_coord_id < 10:
            self.preliminary_trajectory.append((coordinate, time))
        else:
            if self.nmbr_of_coord_id == 10:
                for preliminary_coord in self.preliminary_trajectory:
                    self.trajectory.append(preliminary_coord)
                    self.setVector(preliminary_coord[0])
                self.preliminary_trajectory = []
            self.trajectory.append((coordinate, time))
        self.nmbr_of_coord_id += 1
        self.latency = time - self.clock
        self.clock = time
        if len(self.trajectory) > 1:
            self.setVector(coordinate)
    def setFresh(self, bool):
        self.fresh = bool
    def getData(self):
        return self.data
    def getLatestCoord(self):
        if len(self.preliminary_trajectory) == 0:
            return self.trajectory[len(self.trajectory)-1]
        else:
            return self.preliminary_trajectory[len(self.preliminary_trajectory)-1]
    def getEarliestCoord(self):
        if len(self.preliminary_trajectory) == 0:
            return self.trajectory[0], 'track'
        else:
            return self.preliminary_trajectory[0], 'pre'
    def getLatestAvgVectorShort(self):
        return self.avg_vector_short
    def getLatestAvgVectorLong(self):
        return self.avg_vector_long
    def setVector(self, coord):
        fromCoord = self.trajectory[len(self.trajectory)-2][0]
        toCoord = self.getLatestCoord()[0]
        magnitude, radians = Vector(fromCoord, toCoord, self.latency)
        self.vectors.append((magnitude, radians))
        
        consider_nmbr_of_vectors_short = 10
        consider_nmbr_of_vectors_long = 50
        actualVectorsForAvgShort, actualVectorsForAvgLong = 0, 0
        x_short, y_short = 0, 0
        x_long, y_long = 0, 0
        for index,_ in enumerate(reversed(self.vectors)):
            current_vector = self.vectors[len(self.vectors)-(1+index)] 
            magnitude, angle = current_vector[0], current_vector[1]  
            if index < consider_nmbr_of_vectors_short: 
                x_short += magnitude * math.cos(angle)
                y_short += magnitude * math.sin(angle)
                actualVectorsForAvgShort = index + 1
            else:
                pass
            if index < consider_nmbr_of_vectors_long:
                x_long += magnitude * math.cos(angle)
                y_long += magnitude * math.sin(angle)
                actualVectorsForAvgLong = index + 1
            else: 
                break

        x_avg_short = x_short / (actualVectorsForAvgShort)
        y_avg_short = y_short / (actualVectorsForAvgShort)
        avg_magnitude_short = math.hypot(x_avg_short, y_avg_short)
        avg_radians_short = math.atan2(y_avg_short, x_avg_short)
        self.avg_vector_short = (avg_magnitude_short,avg_radians_short)


        if actualVectorsForAvgLong > 40 and actualVectorsForAvgLong <= consider_nmbr_of_vectors_long:
            x_avg_long = x_long / (actualVectorsForAvgLong)
            y_avg_long = y_long / (actualVectorsForAvgLong)
            avg_magnitude_long = math.hypot(x_avg_long, y_avg_long)
            avg_radians_long = math.atan2(y_avg_long, x_avg_long)
            self.avg_vector_long = (avg_magnitude_long, avg_radians_long)
            self.diff_avg_magnitude = math.sqrt((avg_magnitude_long - avg_magnitude_short)**2)
            self.data.append([self.id, self.diff_avg_magnitude, self.latency, self.avg_vector_short[0], self.avg_vector_short[1],
                                self.avg_vector_long[0], self.avg_vector_long[1], coord[0], coord[1], self.clock])
        self.setFresh(True)
'''
förbättringar:
                    - max ett objekt per closestID per frame (undvika att en blir en annan)
                    - endast några index bakåt (för att objekt som korsar gammal färdväg ej ska byta)

                    vektor - expected next position? drönare lär vara enklare att förutspå än fåglar (värt att klassa på?)
                    plotta vektor i raw : 
                    *** x1 = x0 + magnitude * math.cos(angle_rad) ***
                    *** y1 = y0 + magnitude * math.sin(angle_rad) ***
'''

class TRACKER():
    def __init__(self, maxDistance):
        self.maxDistance = maxDistance
        self.trackedObjects = {}
        self.detectedObjects = {}
        self.assignID = 1
        self.patience = 5 #s

        self.objectsToPop = []
        self.newIteration = True

        self.coordID = 0
        self.contestorNewCoords = []
        self.contestorNewIDs = []
        self.contestorObjectsCoords = []
        self.contestorObjectsIDs = []

    def reset(self):
        self.contestorNewCoords = []
        self.contestorNewIDs = []
        self.contestorObjectsCoords = []
        self.contestorObjectsIDs = []
        self.coordID = 0
        self.objectsToPop = []
        self.newIteration = True

    def track(self, coord, time):
        ''' 
        coord : ((x, y), time) 
        '''
        minDistance = 1e9
        vectorCosineSimularity = 1e9
        closestID = None
        mostSimilarID = None
        assignID = None
        assignScore = 0
        contestor = False
        '''
        mindiff lista som sorterar tillräckligt nära objects diffar 
        prob distr på mag, rad och dist
        '''
        for trackedObject in self.trackedObjects:
            #trackedObject = self.trackedObjects[trackedObject].id
            latency = time - self.trackedObjects[trackedObject].clock
            if latency > self.patience and len(self.trackedObjects[trackedObject].trajectory) < 90:
                if trackedObject not in self.objectsToPop:
                    self.objectsToPop.append(trackedObject)
            else:
                latest = self.trackedObjects[trackedObject].getLatestCoord()
                latestCoord, latestCoordAtTime = latest[0], latest[1]
                dist = euclidianDistance(coord, latestCoord)
                if dist < self.maxDistance: 
                    if trackedObject not in self.contestorObjectsIDs:
                        self.contestorObjectsCoords.append([latestCoord[0], latestCoord[1]])
                        self.contestorObjectsIDs.append(trackedObject)
                    contestor = True
        if not contestor:
            self.trackedObjects[self.assignID] = OBJECT(self.assignID, coord, time)
            self.detectedObjects[self.assignID] = self.trackedObjects[self.assignID]
            self.assignID += 1
            pass
        else:
            if self.coordID not in self.contestorNewIDs:
                self.contestorNewCoords.append([coord[0], coord[1]])
                self.contestorNewIDs.append(self.coordID)
                self.coordID += 1
        '''
        fixa så avstånd viktigare än vector. men inom ett visst threshhold ska vectorliknelse ha betydelse
        '''

    def assign(self, time):
        if not self.contestorObjectsCoords or not self.contestorNewCoords:
            for coord in self.contestorNewCoords:
                self.trackedObjects[self.assignID] = OBJECT(self.assignID, coord, time)
                self.detectedObjects[self.assignID] = self.trackedObjects[self.assignID]
                self.assignID += 1
            self.reset()
            return

        object_id_map = self.contestorObjectsIDs
        coord_list = self.contestorNewCoords

        num_objects = len(object_id_map)
        num_coords = len(coord_list)
        max_dim = max(num_objects, num_coords)

        cost_matrix = np.full((max_dim, max_dim), fill_value=1e6)  # pad if nec

        for i, last_coord in enumerate(self.contestorObjectsCoords):
            object_id = object_id_map[i]
            obj = self.trackedObjects[object_id]

            latency = obj.latency if obj.latency > 1e-5 else 1e-5
            long_vector = obj.getLatestAvgVectorLong()
            short_vector = obj.getLatestAvgVectorShort()

            if long_vector is not None and long_vector[0] > 0:
                predicted_offset = polar_to_cartesian(long_vector[0]*latency, long_vector[1]*latency)
                predicted_vector = long_vector
            #elif short_vector is not None and short_vector[0] > 0:
             #   predicted_offset = polar_to_cartesian(short_vector[0]*latency, short_vector[1]*latency)
              #  predicted_vector = short_vector
            else:
                predicted_offset = np.array([0, 0])
                predicted_vector = None

            predicted_position = np.array(last_coord) + predicted_offset

            for j, coord in enumerate(coord_list):
                coord = np.array(coord)
                distance_to_predicted = np.linalg.norm(predicted_position - coord)

                if distance_to_predicted > self.maxDistance:
                    cost_matrix[i, j] = 1e6
                    continue

                observed_vector = Vector(last_coord, coord, latency)

                if predicted_vector is None or observed_vector[0] <= 0:
                    angle_penalty = 1.0
                else:
                    angle_penalty = 1 - cosine_similarity(predicted_vector, observed_vector)

                alpha = 3.0  # distance
                beta = 7.0  # radians
                vector_confidence = min(len(obj.vectors) / 10, 1.0)
                total_cost = (1 - vector_confidence) * distance_to_predicted + vector_confidence * (alpha * distance_to_predicted + beta * angle_penalty)
                cost_matrix[i, j] = total_cost

        row_ind, col_ind = linear_sum_assignment(cost_matrix)

        assigned_coords = set()
        assigned_objects = set()

        for r, c in zip(row_ind, col_ind):
            if r >= num_objects or c >= num_coords:
                continue
            if cost_matrix[r, c] >= 1e6:
                continue  

            object_id = object_id_map[r]
            coord = coord_list[c]
            if object_id in self.trackedObjects:
                self.trackedObjects[object_id].addCoordinate(coord, time)
                assigned_coords.add(c)
                assigned_objects.add(object_id)

        for i, coord in enumerate(coord_list):
            if i not in assigned_coords:
                self.trackedObjects[self.assignID] = OBJECT(self.assignID, coord, time)
                self.detectedObjects[self.assignID] = self.trackedObjects[self.assignID]
                self.assignID += 1

    def popOldTracks(self):
        for objectToPop in self.objectsToPop:
            self.trackedObjects.pop(objectToPop)

# %%
import numpy as np

class RNN():
    def __init__(self):
        self.LSTM = None
        self.prev = [None, None]

        self.magnitude = None
        self.unitVector = None
        pass
    def forward(self):
        pass
    def backwards(self):
        pass
    def update(self, position):
        position = np.array([position[0], position[1]], dtype=np.float32)
        if self.prev[0] != None:
            vector = position - self.prev                      # vectorize
            # SPEED
            self.magnitude = np.sqrt(np.dot(vector, vector))   # dot and sqrt for magnitude   
            # DIRECTION 
            self.unitVector = vector / self.magnitude if self.magnitude != 0 else np.zeros(2, dtype=np.float32)
            pass

        self.prev = np.array([position[0], position[1]], dtype=np.float32)
        return (self.magnitude, self.unitVector)

# %%
import cv2
import math
import numpy as np

def directional_cone(frame, x0, y0, x1, y1, spread_degrees=45, color=(0, 0, 255), alpha=0.3):
    dx = x1 - x0
    dy = y1 - y0
    direction = math.atan2(dy, dx)
    length = math.hypot(dx, dy)

    # Convert spread angle to radians
    spread = math.radians(spread_degrees)

    # Compute left and right points of the cone base
    left = (
        int(x0 + length * math.cos(direction - spread / 2)),
        int(y0 + length * math.sin(direction - spread / 2))
    )
    right = (
        int(x0 + length * math.cos(direction + spread / 2)),
        int(y0 + length * math.sin(direction + spread / 2))
    )

    # Define triangle points: tip, left, right
    pts = np.array([[x0, y0], left, right], np.int32)
    pts = pts.reshape((-1, 1, 2))

    # Draw transparent triangle
    overlay = frame.copy()
    cv2.fillPoly(overlay, [pts], color)

    # Blend overlay with original frame
    cv2.addWeighted(overlay, alpha, frame, 1 - alpha, 0, frame)

# %%
import os
import cv2
import time
import math
import csv
from ultralytics import YOLO
from queue import Queue

# === Constants ===
SEQUENCE_LENGTH = 90
MODEL_PATH = r"C:\Users\joelw\anaconda3\dronebird\best.pt"
CONFIDENCE_THRESHOLD = 0.2
SCALE_PERCENT = 30
SHOW_FPS = True
SHOW_DISPLAY = True
SHOW_VECTOR_SHORT = True
SHOW_VECTOR_LONG = True
SHOW_DIRECTIONAL_CONES = True
SHOW_TRAJECTORY = True
SHOW_ID_TRACKED = True
SHOW_ID_DETECTED = False
SHOW_YOLO_BOUNDINGBOXES = False
SAVE_OUTPUT = False

# === Colors ===
ORANGE = (0,150,220)
BLUE = (175, 0, 0)
GREEN = (0, 150, 0)
RED = (0, 0, 175)
COLORS = [GREEN, RED, BLUE, ORANGE]

# === Export function ===
def export_sequences(tracked_objects, output_path="all_sequences.csv", label=0):
    rows = []
    sample_entry = None
    for obj in tracked_objects.values():
        data = obj.getData()
        if len(data) < SEQUENCE_LENGTH:
            continue
        if sample_entry is None and data:
            sample_entry = data[0]
        for i in range(0, len(data) - SEQUENCE_LENGTH + 1, SEQUENCE_LENGTH):
            chunk = data[i:i + SEQUENCE_LENGTH]
            flattened = []
            for entry in chunk:
                flattened.extend(entry)
            flattened.append(label)
            rows.append(flattened)
    if not rows:
        print("No valid sequences found.")
        return
    if sample_entry is None:
        print("No sample data to generate headers.")
        return
    feature_names = ["ID", "Diff_Avg_Magnitude", "Latency",
                     "Avg_Vector_Short_Magnitude", "Avg_Vector_Short_Angle",
                     "Avg_Vector_Long_Magnitude", "Avg_Vector_Long_Angle",
                     "X", "Y", "Timestamp"]
    headers = []
    for i in range(SEQUENCE_LENGTH):
        headers.extend([f"{name}_{i}" for name in feature_names])
    headers.append("Label")
    write_header = not os.path.exists(output_path) or os.path.getsize(output_path) == 0
    with open(output_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        if write_header:
            writer.writerow(headers)
        writer.writerows(rows)
    print(f"Saved {len(rows)} sequence(s) to {output_path}")

# === Main processing function ===
def process_video(video_path, label):
    print(f"\n=== Processing: {video_path} ===")

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to read first frame.")
        cap.release()
        return

    original_fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(frame.shape[1] * SCALE_PERCENT / 100)
    height = int(frame.shape[0] * SCALE_PERCENT / 100)

    # Load model and tracker
    model = YOLO(MODEL_PATH)
    model.fuse()
    if model.device.type == 'cuda':
        model.half()

    rnn = RNN()
    tracker = TRACKER(40)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = None
    if SAVE_OUTPUT:
        output_path = f"output_videos/{os.path.splitext(os.path.basename(video_path))[0]}_out.mp4"
        out = cv2.VideoWriter(output_path, fourcc, original_fps, (width, height))

    fps_counter = []
    shutdown = False

    while True:
        ret, full_frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(full_frame, (width, height))
        start_time = time.time()

        current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0

        results = model(frame, conf=CONFIDENCE_THRESHOLD, iou=0.3, verbose = False)
        annotated = results[0].plot() if SHOW_YOLO_BOUNDINGBOXES else frame

        for result in results:
            boxes = result.boxes
            if boxes is not None:
                centers = boxes.xywh[:, :2]
                for center in centers:
                    coord = tuple(map(int, center))
                    tracker.track(coord, current_time)
                tracker.assign(current_time)
                tracker.popOldTracks()
                tracker.reset()

        for id in tracker.trackedObjects:
            obj = tracker.trackedObjects[id]
            for coord in obj.trajectory:
                if SHOW_TRAJECTORY:
                    cv2.circle(annotated, coord[0], 1, COLORS[id % 4])
            if obj.avg_vector_long and obj.fresh:
                mag, angle = obj.avg_vector_long
                x0, y0 = obj.getLatestCoord()[0]
                x1 = int(x0 + mag * math.cos(angle))
                y1 = int(y0 + mag * math.sin(angle))
                if SHOW_VECTOR_LONG:
                    cv2.line(annotated, (x0, y0), (x1, y1), (0, 0, 255), 1)
                if SHOW_DIRECTIONAL_CONES:
                    directional_cone(annotated, x0, y0, x1, y1)
            if obj.avg_vector_short and SHOW_VECTOR_SHORT and obj.fresh:
                mag, angle = obj.avg_vector_short
                x0, y0 = obj.getLatestCoord()[0]
                x1 = int(x0 + mag * math.cos(angle))
                y1 = int(y0 + mag * math.sin(angle))
                cv2.arrowedLine(annotated, (x0, y0), (x1, y1), (255, 0, 0), 1)
            coord, origin = obj.getEarliestCoord()
            if (SHOW_ID_TRACKED and origin == 'track') or SHOW_ID_DETECTED:
                x, y = coord[0]  # Correct: extract from ((x, y), timestamp)
                cv2.putText(annotated, str(id), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, COLORS[id % 4], 1)
            obj.setFresh(False)

        if SHOW_FPS:
            fps = 1.0 / (time.time() - start_time)
            fps_counter.append(fps)
            cv2.putText(annotated, f"{fps:.1f} FPS", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 200), 2)

        if SHOW_DISPLAY:
            cv2.imshow("YOLOv8 Detection", annotated)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                shutdown = True
                break

        if SAVE_OUTPUT and out:
            out.write(annotated)

    cap.release()
    if out:
        out.release()
    if SHOW_DISPLAY:
        cv2.destroyAllWindows()

    if SHOW_FPS and fps_counter:
        print(f"Average FPS: {sum(fps_counter)/len(fps_counter):.2f}")

    export_sequences(tracker.trackedObjects, label=label)
# Out:
# WARNING ⚠️ torchvision==0.20 is incompatible with torch==2.4.
# Run 'pip install torchvision==0.19' to fix torchvision or 'pip install -U torch torchvision' to update both.
# For a full compatibility table see https://github.com/pytorch/vision#installation

# %%
import os
print(os.path.exists("anaconda3/dronebird/raw/Birds"))
# Out:
# True

# %%
import os
import re

VIDEO_DIR = r"C:\Users\joelw\anaconda3\dronebird\raw\Birds"  # FIXED: only relative from current folder
LABEL = 0  # 1 = Drone, 0 = Bird

def natural_key(filename):
    return [int(s) if s.isdigit() else s.lower() for s in re.split(r'(\d+)', filename)]

try:
    print("Current working directory:", os.getcwd())
    print("Looking in directory:", VIDEO_DIR)
    files = os.listdir(VIDEO_DIR)
    print("Files found:", files)

    video_files = sorted([
        os.path.join(VIDEO_DIR, f)
        for f in files
        if f.lower().endswith(".mov")  # Case-insensitive
    ], key=lambda x: natural_key(os.path.basename(x)))

    if not video_files:
        print("No video files found!")

    for path in video_files:
        print("Calling process_video...")
        print(f"\n=== Running on: {path} ===")
        process_video(path, LABEL)
        print("Finished calling process_video.")

except FileNotFoundError as e:
    print(f"Error: {e}")
# Out:
# Current working directory: C:\Users\joelw
# Looking in directory: C:\Users\joelw\anaconda3\dronebird\raw\Birds
# Files found: ['B_1.MOV', 'B_10.MOV', 'B_100.MOV', 'B_101.MOV', 'B_102.MOV', 'B_103.MOV', 'B_104.MOV', 'B_105.MOV', 'B_106.MOV', 'B_107.MOV', 'B_108.MOV', 'B_109.MOV', 'B_11.MOV', 'B_12.MOV', 'B_13.MOV', 'B_14.MOV', 'B_15.MOV', 'B_16.MOV', 'B_17.MOV', 'B_18.MOV', 'B_19.MOV', 'B_2.MOV', 'B_20.MOV', 'B_21.MOV', 'B_22.MOV', 'B_23.MOV', 'B_24.MOV', 'B_25.MOV', 'B_26.MOV', 'B_27.MOV', 'B_28.MOV', 'B_29.MOV', 'B_3.MOV', 'B_30.MOV', 'B_31.MOV', 'B_32.MOV', 'B_33.MOV', 'B_34.MOV', 'B_35.MOV', 'B_36.MOV', 'B_37.MOV', 'B_38.MOV', 'B_39.MOV', 'B_4.MOV', 'B_40.MOV', 'B_41.MOV', 'B_42.MOV', 'B_43.MOV', 'B_44.MOV', 'B_45.MOV', 'B_46.MOV', 'B_47.MOV', 'B_48.MOV', 'B_49.MOV', 'B_5.MOV', 'B_50.MOV', 'B_51.MOV', 'B_52.MOV', 'B_53.MOV', 'B_54.MOV', 'B_55.MOV', 'B_56.MOV', 'B_57.MOV', 'B_58.MOV', 'B_59.MOV', 'B_6.MOV', 'B_60.MOV', 'B_61.MOV', 'B_62.MOV', 'B_63.MOV', 'B_64.MOV', 'B_65.MOV', 'B_66.MOV', 'B_67.MOV', 'B_68.MOV', 'B_69.MOV', 'B_7.MOV', 'B_70.MOV', 'B_71.MOV', 'B_72.MOV', 'B_73.MOV', 'B_74.MOV', 'B_75.MOV', 'B_76.MOV', 'B_77.MOV', 'B_78.MOV', 'B_79.MOV', 'B_8.MOV', 'B_80.MOV', 'B_81.MOV', 'B_82.MOV', 'B_83.MOV', 'B_84.MOV', 'B_85.MOV', 'B_86.MOV', 'B_87.MOV', 'B_88.MOV', 'B_89.MOV', 'B_9.MOV', 'B_90.MOV', 'B_91.MOV', 'B_92.MOV', 'B_93.MOV', 'B_94.MOV', 'B_95.MOV', 'B_96.MOV', 'B_97.MOV', 'B_98.MOV', 'B_99.MOV']
# Calling process_video...
#
# === Running on: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_1.MOV ===
#
# === Processing: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_1.MOV ===
# YOLOv8n summary (fused): 168 layers, 3,005,843 parameters, 0 gradients
#
# 0: 544x960 1 item, 269.1ms
# Speed: 46.1ms preprocess, 269.1ms inference, 17.1ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 188.4ms
# Speed: 9.0ms preprocess, 188.4ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 158.4ms
# Speed: 8.5ms preprocess, 158.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 155.2ms
# Speed: 9.0ms preprocess, 155.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 175.1ms
# Speed: 9.0ms preprocess, 175.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 169.1ms
# Speed: 7.0ms preprocess, 169.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 156.6ms
# Speed: 9.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.8ms
# Speed: 9.0ms preprocess, 138.8ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 155.5ms
# Speed: 7.0ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 159.6ms
# Speed: 7.5ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.3ms
# Speed: 7.0ms preprocess, 151.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 147.0ms
# Speed: 7.0ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 129.9ms
# Speed: 5.0ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 154.5ms
# Speed: 8.0ms preprocess, 154.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 141.6ms
# Speed: 7.0ms preprocess, 141.6ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.0ms
# Speed: 9.0ms preprocess, 151.0ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 140.6ms
# Speed: 6.0ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 154.4ms
# Speed: 6.0ms preprocess, 154.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.2ms
# Speed: 7.0ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 132.9ms
# Speed: 6.0ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.2ms
# Speed: 8.0ms preprocess, 139.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 165.1ms
# Speed: 9.0ms preprocess, 165.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.6ms
# Speed: 5.0ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.4ms
# Speed: 6.0ms preprocess, 126.4ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 120.6ms
# Speed: 5.0ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 127.5ms
# Speed: 8.0ms preprocess, 127.5ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 156.1ms
# Speed: 7.0ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 3 items, 137.0ms
# Speed: 7.0ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.1ms
# Speed: 6.0ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 149.9ms
# Speed: 7.0ms preprocess, 149.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.3ms
# Speed: 7.0ms preprocess, 139.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 155.5ms
# Speed: 6.0ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 154.4ms
# Speed: 6.0ms preprocess, 154.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 130.1ms
# Speed: 5.0ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 3 items, 143.6ms
# Speed: 6.5ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 157.3ms
# Speed: 5.0ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 144.0ms
# Speed: 8.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 145.3ms
# Speed: 8.0ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 162.5ms
# Speed: 6.0ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.9ms
# Speed: 7.0ms preprocess, 138.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.1ms
# Speed: 4.5ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.9ms
# Speed: 6.0ms preprocess, 134.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.2ms
# Speed: 7.0ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 165.5ms
# Speed: 7.0ms preprocess, 165.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.2ms
# Speed: 5.0ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 150.1ms
# Speed: 7.0ms preprocess, 150.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 140.1ms
# Speed: 5.0ms preprocess, 140.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 130.1ms
# Speed: 7.0ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 154.7ms
# Speed: 6.0ms preprocess, 154.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.1ms
# Speed: 8.5ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.1ms
# Speed: 7.0ms preprocess, 139.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 135.6ms
# Speed: 7.0ms preprocess, 135.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 146.1ms
# Speed: 6.0ms preprocess, 146.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 139.8ms
# Speed: 7.0ms preprocess, 139.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 145.5ms
# Speed: 8.0ms preprocess, 145.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 153.0ms
# Speed: 6.5ms preprocess, 153.0ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 202.2ms
# Speed: 7.0ms preprocess, 202.2ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 127.5ms
# Speed: 5.0ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 122.7ms
# Speed: 5.0ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 125.6ms
# Speed: 7.0ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 127.6ms
# Speed: 7.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 129.5ms
# Speed: 7.0ms preprocess, 129.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 124.9ms
# Speed: 5.0ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 121.6ms
# Speed: 8.0ms preprocess, 121.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 142.1ms
# Speed: 6.0ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 133.5ms
# Speed: 10.0ms preprocess, 133.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 149.3ms
# Speed: 7.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 153.3ms
# Speed: 8.0ms preprocess, 153.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 137.6ms
# Speed: 7.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 136.5ms
# Speed: 7.0ms preprocess, 136.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 141.6ms
# Speed: 5.0ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 156.1ms
# Speed: 8.0ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 124.1ms
# Speed: 5.0ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 141.5ms
# Speed: 10.0ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 131.1ms
# Speed: 6.0ms preprocess, 131.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 139.6ms
# Speed: 7.0ms preprocess, 139.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 139.1ms
# Speed: 7.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 171.6ms
# Speed: 7.0ms preprocess, 171.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 181.1ms
# Speed: 9.0ms preprocess, 181.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 195.1ms
# Speed: 13.0ms preprocess, 195.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 138.6ms
# Speed: 8.0ms preprocess, 138.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.0ms
# Speed: 9.0ms preprocess, 142.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 140.5ms
# Speed: 7.0ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 145.4ms
# Speed: 8.0ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 157.3ms
# Speed: 9.0ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 134.3ms
# Speed: 10.0ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 143.9ms
# Speed: 7.0ms preprocess, 143.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 129.1ms
# Speed: 6.0ms preprocess, 129.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 140.7ms
# Speed: 7.0ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.6ms
# Speed: 9.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 229.0ms
# Speed: 7.0ms preprocess, 229.0ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 141.6ms
# Speed: 8.0ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 149.9ms
# Speed: 6.0ms preprocess, 149.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 151.1ms
# Speed: 8.9ms preprocess, 151.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 139.1ms
# Speed: 9.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 156.2ms
# Speed: 7.0ms preprocess, 156.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 122.0ms
# Speed: 7.0ms preprocess, 122.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.5ms
# Speed: 6.0ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 123.3ms
# Speed: 6.0ms preprocess, 123.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 134.2ms
# Speed: 6.0ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 228.5ms
# Speed: 8.0ms preprocess, 228.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 161.1ms
# Speed: 8.0ms preprocess, 161.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 154.0ms
# Speed: 9.0ms preprocess, 154.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 152.6ms
# Speed: 7.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 146.6ms
# Speed: 7.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 152.1ms
# Speed: 10.0ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.5ms
# Speed: 6.0ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 133.1ms
# Speed: 6.0ms preprocess, 133.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.6ms
# Speed: 7.0ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 2 items, 127.1ms
# Speed: 7.0ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.7ms
# Speed: 6.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 124.3ms
# Speed: 5.5ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 124.6ms
# Speed: 6.0ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 119.9ms
# Speed: 6.0ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 120.3ms
# Speed: 6.0ms preprocess, 120.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 163.1ms
# Speed: 5.0ms preprocess, 163.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 149.6ms
# Speed: 7.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 156.5ms
# Speed: 8.0ms preprocess, 156.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 146.9ms
# Speed: 8.0ms preprocess, 146.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 176.5ms
# Speed: 10.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 176.9ms
# Speed: 5.0ms preprocess, 176.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 136.6ms
# Speed: 7.0ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 143.3ms
# Speed: 9.5ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.5ms
# Speed: 7.0ms preprocess, 125.5ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 181.1ms
# Speed: 5.0ms preprocess, 181.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 122.5ms
# Speed: 5.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.7ms
# Speed: 6.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 122.8ms
# Speed: 8.0ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.1ms
# Speed: 7.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 124.2ms
# Speed: 6.0ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.9ms
# Speed: 6.0ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.5ms
# Speed: 5.0ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.9ms
# Speed: 7.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 132.0ms
# Speed: 5.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 136.6ms
# Speed: 8.0ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.5ms
# Speed: 7.0ms preprocess, 128.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 123.5ms
# Speed: 6.0ms preprocess, 123.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.5ms
# Speed: 8.0ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.2ms
# Speed: 6.0ms preprocess, 126.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 124.7ms
# Speed: 8.0ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.2ms
# Speed: 7.0ms preprocess, 125.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.3ms
# Speed: 6.0ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 123.9ms
# Speed: 6.0ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 121.0ms
# Speed: 6.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.6ms
# Speed: 6.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 188.2ms
# Speed: 6.0ms preprocess, 188.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.1ms
# Speed: 6.0ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.8ms
# Speed: 6.0ms preprocess, 142.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 124.0ms
# Speed: 7.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.6ms
# Speed: 5.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.6ms
# Speed: 6.0ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.0ms
# Speed: 6.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 131.5ms
# Speed: 6.0ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.1ms
# Speed: 8.0ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.8ms
# Speed: 6.0ms preprocess, 128.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 130.0ms
# Speed: 5.5ms preprocess, 130.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.1ms
# Speed: 7.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 145.2ms
# Speed: 8.0ms preprocess, 145.2ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 155.5ms
# Speed: 6.5ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 164.1ms
# Speed: 8.0ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.1ms
# Speed: 7.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.3ms
# Speed: 7.0ms preprocess, 135.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 143.8ms
# Speed: 6.0ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 132.5ms
# Speed: 6.0ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 200.6ms
# Speed: 9.0ms preprocess, 200.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 153.5ms
# Speed: 7.0ms preprocess, 153.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.1ms
# Speed: 6.0ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 137.4ms
# Speed: 6.0ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 150.4ms
# Speed: 6.0ms preprocess, 150.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 162.3ms
# Speed: 6.5ms preprocess, 162.3ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 181.7ms
# Speed: 10.0ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 166.6ms
# Speed: 7.0ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 170.8ms
# Speed: 7.0ms preprocess, 170.8ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 162.7ms
# Speed: 8.0ms preprocess, 162.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 152.4ms
# Speed: 9.0ms preprocess, 152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 152.6ms
# Speed: 7.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 148.1ms
# Speed: 8.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 136.6ms
# Speed: 7.0ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 147.4ms
# Speed: 7.0ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 137.5ms
# Speed: 6.5ms preprocess, 137.5ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 196.1ms
# Speed: 8.0ms preprocess, 196.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.5ms
# Speed: 9.0ms preprocess, 148.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 124.6ms
# Speed: 7.5ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 130.6ms
# Speed: 6.0ms preprocess, 130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 137.5ms
# Speed: 6.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 149.1ms
# Speed: 8.0ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 152.8ms
# Speed: 7.0ms preprocess, 152.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 153.9ms
# Speed: 11.0ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.5ms
# Speed: 7.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 141.2ms
# Speed: 8.0ms preprocess, 141.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 125.6ms
# Speed: 6.0ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.1ms
# Speed: 7.0ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.4ms
# Speed: 6.0ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.6ms
# Speed: 7.5ms preprocess, 138.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 120.5ms
# Speed: 6.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.1ms
# Speed: 6.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 196.5ms
# Speed: 9.0ms preprocess, 196.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 143.8ms
# Speed: 7.0ms preprocess, 143.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 148.1ms
# Speed: 5.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 144.1ms
# Speed: 7.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.6ms
# Speed: 6.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 138.6ms
# Speed: 8.0ms preprocess, 138.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 134.1ms
# Speed: 8.0ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.6ms
# Speed: 7.0ms preprocess, 148.6ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.9ms
# Speed: 7.0ms preprocess, 134.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 120.9ms
# Speed: 5.0ms preprocess, 120.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 125.6ms
# Speed: 6.0ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 137.4ms
# Speed: 5.0ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.5ms
# Speed: 7.0ms preprocess, 128.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.8ms
# Speed: 7.0ms preprocess, 126.8ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 183.2ms
# Speed: 6.0ms preprocess, 183.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 135.1ms
# Speed: 7.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 124.9ms
# Speed: 9.0ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 124.6ms
# Speed: 6.0ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.9ms
# Speed: 6.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.1ms
# Speed: 6.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 141.5ms
# Speed: 7.0ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 166.6ms
# Speed: 9.5ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.1ms
# Speed: 6.0ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.4ms
# Speed: 7.0ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.4ms
# Speed: 6.0ms preprocess, 125.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 156.1ms
# Speed: 7.0ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 167.1ms
# Speed: 6.0ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 193.1ms
# Speed: 6.0ms preprocess, 193.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 121.8ms
# Speed: 5.0ms preprocess, 121.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.5ms
# Speed: 7.0ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.1ms
# Speed: 7.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.0ms
# Speed: 7.0ms preprocess, 135.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.0ms
# Speed: 9.5ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.0ms
# Speed: 5.0ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 133.6ms
# Speed: 6.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.7ms
# Speed: 7.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.7ms
# Speed: 6.0ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 131.0ms
# Speed: 6.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 144.4ms
# Speed: 9.0ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.2ms
# Speed: 5.0ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 190.1ms
# Speed: 7.0ms preprocess, 190.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 121.2ms
# Speed: 7.0ms preprocess, 121.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 129.3ms
# Speed: 5.0ms preprocess, 129.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.5ms
# Speed: 7.0ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.3ms
# Speed: 8.0ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 127.0ms
# Speed: 5.0ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 129.9ms
# Speed: 5.0ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 126.6ms
# Speed: 7.0ms preprocess, 126.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.3ms
# Speed: 6.0ms preprocess, 128.3ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 128.2ms
# Speed: 7.0ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 132.6ms
# Speed: 7.0ms preprocess, 132.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.5ms
# Speed: 6.0ms preprocess, 142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 122.7ms
# Speed: 5.0ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 177.1ms
# Speed: 7.0ms preprocess, 177.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 164.1ms
# Speed: 8.0ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.8ms
# Speed: 6.0ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 168.1ms
# Speed: 7.0ms preprocess, 168.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 153.6ms
# Speed: 8.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 145.6ms
# Speed: 7.0ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 144.6ms
# Speed: 7.0ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.5ms
# Speed: 7.5ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.1ms
# Speed: 6.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 143.6ms
# Speed: 10.0ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 139.5ms
# Speed: 6.0ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 147.1ms
# Speed: 7.0ms preprocess, 147.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 206.1ms
# Speed: 6.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 153.6ms
# Speed: 7.0ms preprocess, 153.6ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 152.4ms
# Speed: 8.0ms preprocess, 152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.2ms
# Speed: 6.0ms preprocess, 142.2ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 153.6ms
# Speed: 8.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 158.6ms
# Speed: 7.0ms preprocess, 158.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 141.3ms
# Speed: 7.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 149.1ms
# Speed: 7.0ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 191.1ms
# Speed: 7.0ms preprocess, 191.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 170.1ms
# Speed: 10.0ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 150.9ms
# Speed: 7.0ms preprocess, 150.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 150.3ms
# Speed: 7.0ms preprocess, 150.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 244.8ms
# Speed: 8.0ms preprocess, 244.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 164.6ms
# Speed: 10.0ms preprocess, 164.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 128.5ms
# Speed: 7.0ms preprocess, 128.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 151.4ms
# Speed: 8.0ms preprocess, 151.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 153.1ms
# Speed: 7.0ms preprocess, 153.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 147.5ms
# Speed: 8.0ms preprocess, 147.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 161.6ms
# Speed: 8.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 144.1ms
# Speed: 9.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 192.1ms
# Speed: 11.0ms preprocess, 192.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 151.6ms
# Speed: 7.5ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 150.1ms
# Speed: 5.0ms preprocess, 150.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 232.9ms
# Speed: 11.0ms preprocess, 232.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.8ms
# Speed: 8.0ms preprocess, 151.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 152.2ms
# Speed: 6.5ms preprocess, 152.2ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.6ms
# Speed: 8.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 133.7ms
# Speed: 7.0ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 134.1ms
# Speed: 6.0ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.7ms
# Speed: 10.0ms preprocess, 138.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.9ms
# Speed: 6.0ms preprocess, 148.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 130.5ms
# Speed: 10.0ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 126.5ms
# Speed: 6.0ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 148.6ms
# Speed: 6.5ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 192.1ms
# Speed: 7.0ms preprocess, 192.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 145.1ms
# Speed: 7.0ms preprocess, 145.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.1ms
# Speed: 8.0ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 140.5ms
# Speed: 9.0ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.8ms
# Speed: 8.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 131.4ms
# Speed: 6.5ms preprocess, 131.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 135.0ms
# Speed: 8.0ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 125.3ms
# Speed: 8.0ms preprocess, 125.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 127.3ms
# Speed: 6.0ms preprocess, 127.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.9ms
# Speed: 8.0ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 184.6ms
# Speed: 6.0ms preprocess, 184.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 166.0ms
# Speed: 8.0ms preprocess, 166.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.6ms
# Speed: 9.5ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 145.0ms
# Speed: 8.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.1ms
# Speed: 7.0ms preprocess, 151.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 157.3ms
# Speed: 7.0ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 159.5ms
# Speed: 10.0ms preprocess, 159.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 135.6ms
# Speed: 7.5ms preprocess, 135.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 136.9ms
# Speed: 7.0ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 126.9ms
# Speed: 7.0ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 188.1ms
# Speed: 6.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.0ms
# Speed: 7.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 136.0ms
# Speed: 6.0ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.1ms
# Speed: 5.0ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 138.9ms
# Speed: 8.0ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 127.6ms
# Speed: 6.0ms preprocess, 127.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 123.5ms
# Speed: 6.0ms preprocess, 123.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.6ms
# Speed: 6.2ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 129.2ms
# Speed: 8.0ms preprocess, 129.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.4ms
# Speed: 6.0ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 191.1ms
# Speed: 8.0ms preprocess, 191.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.6ms
# Speed: 7.5ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 127.6ms
# Speed: 6.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 125.2ms
# Speed: 6.0ms preprocess, 125.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 128.9ms
# Speed: 5.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 144.1ms
# Speed: 7.0ms preprocess, 144.1ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 161.1ms
# Speed: 8.0ms preprocess, 161.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 168.1ms
# Speed: 7.0ms preprocess, 168.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 139.5ms
# Speed: 6.0ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 225.2ms
# Speed: 7.0ms preprocess, 225.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
# Average FPS: 6.41
# Saved 1 sequence(s) to all_sequences.csv
# Finished calling process_video.
# Calling process_video...
#
# === Running on: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_2.MOV ===
#
# === Processing: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_2.MOV ===
# YOLOv8n summary (fused): 168 layers, 3,005,843 parameters, 0 gradients
#
# 0: 608x960 1 item, 250.7ms
# Speed: 16.5ms preprocess, 250.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 222.4ms
# Speed: 11.0ms preprocess, 222.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 187.1ms
# Speed: 7.0ms preprocess, 187.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 176.3ms
# Speed: 10.0ms preprocess, 176.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 178.1ms
# Speed: 11.0ms preprocess, 178.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 181.5ms
# Speed: 8.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 170.5ms
# Speed: 8.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 159.3ms
# Speed: 11.0ms preprocess, 159.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 207.1ms
# Speed: 9.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 168.2ms
# Speed: 8.5ms preprocess, 168.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 148.6ms
# Speed: 8.5ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 143.1ms
# Speed: 8.0ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 152.1ms
# Speed: 8.0ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 162.1ms
# Speed: 8.0ms preprocess, 162.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 161.8ms
# Speed: 11.0ms preprocess, 161.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 151.8ms
# Speed: 8.0ms preprocess, 151.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 170.5ms
# Speed: 9.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 203.2ms
# Speed: 10.0ms preprocess, 203.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 174.1ms
# Speed: 9.0ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 160.1ms
# Speed: 8.0ms preprocess, 160.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 161.1ms
# Speed: 9.0ms preprocess, 161.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 174.1ms
# Speed: 9.0ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 608x960 1 item, 171.3ms
# ...
#
# 0: 544x960 (no detections), 170.1ms
# Speed: 7.0ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 195.1ms
# Speed: 8.0ms preprocess, 195.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 202.9ms
# Speed: 12.5ms preprocess, 202.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 181.7ms
# Speed: 6.0ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 174.1ms
# Speed: 9.0ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 163.8ms
# Speed: 8.6ms preprocess, 163.8ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 191.7ms
# Speed: 6.6ms preprocess, 191.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 152.5ms
# Speed: 5.5ms preprocess, 152.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 203.7ms
# Speed: 7.5ms preprocess, 203.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 170.1ms
# Speed: 8.0ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 141.5ms
# Speed: 8.0ms preprocess, 141.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.5ms
# Speed: 7.0ms preprocess, 131.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 135.1ms
# Speed: 8.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.5ms
# Speed: 6.0ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 127.6ms
# Speed: 7.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 152.1ms
# Speed: 7.0ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 128.8ms
# Speed: 7.0ms preprocess, 128.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 149.6ms
# Speed: 7.5ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 175.1ms
# Speed: 8.0ms preprocess, 175.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 159.1ms
# Speed: 7.0ms preprocess, 159.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 170.1ms
# Speed: 11.0ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.1ms
# Speed: 9.0ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.6ms
# Speed: 7.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 151.6ms
# Speed: 8.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 131.6ms
# Speed: 6.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 125.1ms
# Speed: 8.0ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 150.5ms
# Speed: 8.0ms preprocess, 150.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 157.6ms
# Speed: 8.5ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 146.1ms
# Speed: 9.0ms preprocess, 146.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 144.1ms
# Speed: 7.0ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 158.1ms
# Speed: 6.0ms preprocess, 158.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 142.6ms
# Speed: 6.0ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 145.6ms
# Speed: 6.5ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 126.1ms
# Speed: 8.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.5ms
# Speed: 6.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 144.6ms
# Speed: 8.0ms preprocess, 144.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 138.1ms
# Speed: 7.0ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.6ms
# Speed: 6.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 137.6ms
# Speed: 7.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 140.1ms
# Speed: 7.0ms preprocess, 140.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 130.5ms
# Speed: 6.0ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 126.6ms
# Speed: 8.0ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 139.1ms
# Speed: 6.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 138.5ms
# Speed: 6.0ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.6ms
# Speed: 7.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 185.1ms
# Speed: 6.0ms preprocess, 185.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 149.1ms
# Speed: 8.0ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 205.1ms
# Speed: 7.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 166.1ms
# Speed: 8.0ms preprocess, 166.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 132.1ms
# Speed: 7.0ms preprocess, 132.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 129.5ms
# Speed: 6.0ms preprocess, 129.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 131.6ms
# Speed: 7.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
# Average FPS: 5.94
# No valid sequences found.
# Finished calling process_video.
# Calling process_video...
#
# === Running on: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_109.MOV ===
#
# === Processing: C:\Users\joelw\anaconda3\dronebird\raw\Birds\B_109.MOV ===
# YOLOv8n summary (fused): 168 layers, 3,005,843 parameters, 0 gradients
#
# 0: 544x960 1 item, 235.6ms
# Speed: 7.0ms preprocess, 235.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 225.7ms
# Speed: 10.0ms preprocess, 225.7ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 217.1ms
# Speed: 10.0ms preprocess, 217.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 238.6ms
# Speed: 12.0ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 183.1ms
# Speed: 9.0ms preprocess, 183.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 179.1ms
# Speed: 11.0ms preprocess, 179.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 163.1ms
# Speed: 6.0ms preprocess, 163.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 159.1ms
# Speed: 7.0ms preprocess, 159.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 163.1ms
# Speed: 7.0ms preprocess, 163.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 187.1ms
# Speed: 19.0ms preprocess, 187.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 171.6ms
# Speed: 8.0ms preprocess, 171.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 159.6ms
# Speed: 8.0ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 188.6ms
# Speed: 8.5ms preprocess, 188.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 220.1ms
# Speed: 8.0ms preprocess, 220.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 198.1ms
# Speed: 9.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 172.6ms
# Speed: 9.0ms preprocess, 172.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 173.6ms
# Speed: 7.0ms preprocess, 173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 170.6ms
# Speed: 8.0ms preprocess, 170.6ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 218.1ms
# Speed: 7.0ms preprocess, 218.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 183.1ms
# Speed: 7.0ms preprocess, 183.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 178.5ms
# Speed: 8.5ms preprocess, 178.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 171.6ms
# Speed: 8.0ms preprocess, 171.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 168.6ms
# Speed: 8.0ms preprocess, 168.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 167.6ms
# Speed: 7.0ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 190.1ms
# Speed: 8.0ms preprocess, 190.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 172.1ms
# Speed: 7.0ms preprocess, 172.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 239.1ms
# Speed: 9.0ms preprocess, 239.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 171.6ms
# Speed: 7.0ms preprocess, 171.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 183.1ms
# Speed: 9.0ms preprocess, 183.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 166.1ms
# Speed: 10.0ms preprocess, 166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 169.1ms
# Speed: 7.0ms preprocess, 169.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 133.6ms
# Speed: 8.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 186.1ms
# Speed: 7.0ms preprocess, 186.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 193.1ms
# Speed: 8.0ms preprocess, 193.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 215.1ms
# Speed: 7.0ms preprocess, 215.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 208.1ms
# Speed: 8.0ms preprocess, 208.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 189.1ms
# Speed: 7.0ms preprocess, 189.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 174.1ms
# Speed: 7.0ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 176.1ms
# Speed: 7.0ms preprocess, 176.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 175.1ms
# Speed: 7.0ms preprocess, 175.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 203.1ms
# Speed: 10.0ms preprocess, 203.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 187.1ms
# Speed: 8.0ms preprocess, 187.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 176.1ms
# Speed: 8.0ms preprocess, 176.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 188.1ms
# Speed: 7.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 176.1ms
# Speed: 8.0ms preprocess, 176.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 186.1ms
# Speed: 10.0ms preprocess, 186.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 178.6ms
# Speed: 7.5ms preprocess, 178.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 167.6ms
# Speed: 9.0ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 188.1ms
# Speed: 7.0ms preprocess, 188.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 175.1ms
# Speed: 7.0ms preprocess, 175.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 172.1ms
# Speed: 7.0ms preprocess, 172.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 180.1ms
# Speed: 8.0ms preprocess, 180.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 143.1ms
# Speed: 7.0ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 140.6ms
# Speed: 7.0ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 138.5ms
# Speed: 6.0ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 192.1ms
# Speed: 7.0ms preprocess, 192.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 209.1ms
# Speed: 7.0ms preprocess, 209.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 227.1ms
# Speed: 8.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 205.1ms
# Speed: 12.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 176.1ms
# Speed: 9.0ms preprocess, 176.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 199.1ms
# Speed: 7.0ms preprocess, 199.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 219.1ms
# Speed: 15.5ms preprocess, 219.1ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 1 item, 142.1ms
# Speed: 9.0ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 544x960 (no detections), 142.5ms
# Speed: 6.0ms preprocess, 142.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 960)
# Average FPS: 5.15
# No valid sequences found.
# Finished calling process_video.
